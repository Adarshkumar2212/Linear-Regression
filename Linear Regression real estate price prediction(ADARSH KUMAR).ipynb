# %%
import numpy as np
import pandas as pd 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Real estate.csv', index_col='No')
df.head(5)
# Out:
#     X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# No
# 1              2012.917          32.0                                84.87882
# 2              2012.917          19.5                               306.59470
# 3              2013.583          13.3                               561.98450
# 4              2013.500          13.3                               561.98450
# 5              2012.833           5.0                               390.56840
#
#     X4 number of convenience stores  X5 latitude  X6 longitude  \
# No
# 1                                10     24.98298     121.54024
# 2                                 9     24.98034     121.53951
# 3                                 5     24.98746     121.54391
# 4                                 5     24.98746     121.54391
# 5                                 5     24.97937     121.54245
#
#     Y house price of unit area
# No
# 1                         37.9
# 2                         42.2
# 3                         47.3
# 4                         54.8
# 5                         43.1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 414 entries, 1 to 414
# Data columns (total 7 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   X1 transaction date                     414 non-null    float64
#  1   X2 house age                            414 non-null    float64
#  2   X3 distance to the nearest MRT station  414 non-null    float64
#  3   X4 number of convenience stores         414 non-null    int64
#  4   X5 latitude                             414 non-null    float64
#  5   X6 longitude                            414 non-null    float64
#  6   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 25.9 KB

# %%
df.describe()
# Out:
#        X1 transaction date  X2 house age  \
# count           414.000000    414.000000
# mean           2013.148971     17.712560
# std               0.281967     11.392485
# min            2012.667000      0.000000
# 25%            2012.917000      9.025000
# 50%            2013.167000     16.100000
# 75%            2013.417000     28.150000
# max            2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
#        X4 number of convenience stores  X5 latitude  X6 longitude  \
# count                       414.000000   414.000000    414.000000
# mean                          4.094203    24.969030    121.533361
# std                           2.945562     0.012410      0.015347
# min                           0.000000    24.932070    121.473530
# 25%                           1.000000    24.963000    121.528085
# 50%                           4.000000    24.971100    121.538630
# 75%                           6.000000    24.977455    121.543305
# max                          10.000000    25.014590    121.566270
#
#        Y house price of unit area
# count                  414.000000
# mean                    37.980193
# std                     13.606488
# min                      7.600000
# 25%                     27.700000
# 50%                     38.450000
# 75%                     46.600000
# max                    117.500000

# %%
plt.figure(figsize=(16,6))
corr = df.corr()
sns.set_theme(style ='white')
heat_map = sns.heatmap(corr,vmin = -1, vmax = 1, square = True, annot = True, cmap = 'coolwarm')
heat_map.set_title('Correlation Heatmap', fontdict={'fontsize':18} )
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
df.columns
# Out:
# Index(['X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
df['X3 distance to the nearest MRT station'].value_counts()
print(df['X3 distance to the nearest MRT station'].max())
print(df['X3 distance to the nearest MRT station'].min())
# Out:
# 6488.021
# 23.38284

# %%
df['X4 number of convenience stores'].value_counts()
# Out:
# 0     67
# 5     67
# 1     46
# 3     46
# 6     37
# 4     31
# 7     31
# 8     30
# 9     25
# 2     24
# 10    10
# Name: X4 number of convenience stores, dtype: int64

# %%
x_1 = df['X4 number of convenience stores']
y_1 = df['X3 distance to the nearest MRT station']
sns.scatterplot(x_1, y_1)
# Out:
# C:\Users\91828\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='X4 number of convenience stores', ylabel='X3 distance to the nearest MRT station'>

# %%
from datetime import datetime
df['X1 transaction date'] = pd.to_datetime(df['X1 transaction date'])


df.head()
# Out:
#              X1 transaction date  X2 house age  \
# No
# 1  1970-01-01 00:00:00.000002012          32.0
# 2  1970-01-01 00:00:00.000002012          19.5
# 3  1970-01-01 00:00:00.000002013          13.3
# 4  1970-01-01 00:00:00.000002013          13.3
# 5  1970-01-01 00:00:00.000002012           5.0
#
#     X3 distance to the nearest MRT station  X4 number of convenience stores  \
# No
# 1                                 84.87882                               10
# 2                                306.59470                                9
# 3                                561.98450                                5
# 4                                561.98450                                5
# 5                                390.56840                                5
#
#     X5 latitude  X6 longitude  Y house price of unit area
# No
# 1      24.98298     121.54024                        37.9
# 2      24.98034     121.53951                        42.2
# 3      24.98746     121.54391                        47.3
# 4      24.98746     121.54391                        54.8
# 5      24.97937     121.54245                        43.1

# %%
df['X2 house age'].value_counts()
# Out:
# 0.0     17
# 13.6     7
# 16.2     6
# 13.2     6
# 16.4     6
#         ..
# 12.3     1
# 39.6     1
# 9.7      1
# 37.3     1
# 25.9     1
# Name: X2 house age, Length: 236, dtype: int64

# %%
print(df['X2 house age'].max())
print(df['X2 house age'].min())
# Out:
# 43.8
# 0.0

# %%
print(df['X2 house age'].max())
print(df['X2 house age'].min())
# Out:
# 43.8
# 0.0

# %%
df.tail(10)
# Out:
#               X1 transaction date  X2 house age  \
# No
# 405 1970-01-01 00:00:00.000002013          16.4
# 406 1970-01-01 00:00:00.000002012          23.0
# 407 1970-01-01 00:00:00.000002013           1.9
# 408 1970-01-01 00:00:00.000002013           5.2
# 409 1970-01-01 00:00:00.000002013          18.5
# 410 1970-01-01 00:00:00.000002013          13.7
# 411 1970-01-01 00:00:00.000002012           5.6
# 412 1970-01-01 00:00:00.000002013          18.8
# 413 1970-01-01 00:00:00.000002013           8.1
# 414 1970-01-01 00:00:00.000002013           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# No
# 405                               289.32480                                5
# 406                               130.99450                                6
# 407                               372.13860                                7
# 408                              2408.99300                                0
# 409                              2175.74400                                3
# 410                              4082.01500                                0
# 411                                90.45606                                9
# 412                               390.96960                                7
# 413                               104.81010                                5
# 414                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# No
# 405     24.98203     121.54348                        41.2
# 406     24.95663     121.53765                        37.2
# 407     24.97293     121.54026                        40.5
# 408     24.95505     121.55964                        22.3
# 409     24.96330     121.51243                        28.1
# 410     24.94155     121.50381                        15.4
# 411     24.97433     121.54310                        50.0
# 412     24.97923     121.53986                        40.6
# 413     24.96674     121.54067                        52.5
# 414     24.97433     121.54310                        63.9

# %%
df['X2 house age']
# Out:
# No
# 1      32.0
# 2      19.5
# 3      13.3
# 4      13.3
# 5       5.0
#        ...
# 410    13.7
# 411     5.6
# 412    18.8
# 413     8.1
# 414     6.5
# Name: X2 house age, Length: 414, dtype: float64

# %%
df.shape
# Out:
# (414, 7)

# %%
df = df.drop('X1 transaction date', axis =1)
df.head()
# Out:
#     X2 house age  X3 distance to the nearest MRT station  \
# No
# 1           32.0                                84.87882
# 2           19.5                               306.59470
# 3           13.3                               561.98450
# 4           13.3                               561.98450
# 5            5.0                               390.56840
#
#     X4 number of convenience stores  X5 latitude  X6 longitude  \
# No
# 1                                10     24.98298     121.54024
# 2                                 9     24.98034     121.53951
# 3                                 5     24.98746     121.54391
# 4                                 5     24.98746     121.54391
# 5                                 5     24.97937     121.54245
#
#     Y house price of unit area
# No
# 1                         37.9
# 2                         42.2
# 3                         47.3
# 4                         54.8
# 5                         43.1

# %%
plt.figure(figsize=(16,6))
hist_graph = sns.histplot(df, x = 'X2 house age', color ='g')
hist_graph.set_title('Histogram for house age', fontdict={'fontsize': 18})
# Out:
# Text(0.5, 1.0, 'Histogram for house age')

# %%
plt.figure(figsize=(16,6))
hist_graph = sns.histplot(df, x = 'X4 number of convenience stores', color ='r')
hist_graph.set_title('Histogram for number of convenience stores', fontdict={'fontsize': 18})
# Out:
# Text(0.5, 1.0, 'Histogram for number of convenience stores')

# %%
scatter_p_x3 = sns.scatterplot(x = df['X3 distance to the nearest MRT station'], y =df['Y house price of unit area'])
scatter_p_x3.set_title('Scatter Plot for X3 distance to the nearest MRT station')
# Out:
# Text(0.5, 1.0, 'Scatter Plot for X3 distance to the nearest MRT station')

# %%
scatter_p_x4 = sns.scatterplot(x = df['X4 number of convenience stores'], y =df['Y house price of unit area'])
scatter_p_x4.set_title('Scatter Plot for X4 number of convenience stores')
# Out:
# Text(0.5, 1.0, 'Scatter Plot for X4 number of convenience stores')

# %%
scatter_p_x5 = sns.scatterplot(x = df['X5 latitude'], y =df['Y house price of unit area'])
scatter_p_x5.set_title('Scatter Plot for X5 latitude')
# Out:
# Text(0.5, 1.0, 'Scatter Plot for X5 latitude')

# %%
plt.figure(figsize=(20,10))
reg_plot_x5_log=sns.regplot(x = df['X5 latitude'], y =df['Y house price of unit area'], order=2)

# %%
plt.figure(figsize=(20, 6))
line_p_x5 = sns.lineplot(x = df['X5 latitude'], y =df['Y house price of unit area'], marker = True)

# %%
hist_plot_x5_log=sns.displot(x = df['X5 latitude'])

# %%
scatter_p_x6 = sns.scatterplot(x = df['X6 longitude'], y =df['Y house price of unit area'])
scatter_p_x6.set_title('Scatter Plot for X6 longitude')
# Out:
# Text(0.5, 1.0, 'Scatter Plot for X6 longitude')

# %%
hist_plot_x6=sns.displot(x = df['X6 longitude'])

# %%
line_p_x6 = sns.lineplot(x = df['X6 longitude'], y =df['Y house price of unit area'], marker = True)

# %%
df.columns
# Out:
# Index(['X2 house age', 'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 414 entries, 1 to 414
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   X2 house age                            414 non-null    float64
#  1   X3 distance to the nearest MRT station  414 non-null    float64
#  2   X4 number of convenience stores         414 non-null    int64
#  3   X5 latitude                             414 non-null    float64
#  4   X6 longitude                            414 non-null    float64
#  5   Y house price of unit area              414 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 22.6 KB

# %%
msk = np.random.rand(len(df)) < 0.8
train = df[msk]
test = df[~msk]

# %%
train.columns
# Out:
# Index(['X2 house age', 'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model
train_x = np.asanyarray(train[['X2 house age', 'X3 distance to the nearest MRT station',
       'X4 number of convenience stores', 'X5 latitude', 'X6 longitude'
       ]])
train_y = np.asanyarray(train[['Y house price of unit area']])

test_x = np.asanyarray(test[['X2 house age', 'X3 distance to the nearest MRT station',
       'X4 number of convenience stores', 'X5 latitude', 'X6 longitude']])
test_y = np.asanyarray(test[['Y house price of unit area']])


poly = PolynomialFeatures(degree=2)
train_x_poly = poly.fit_transform(train_x)
train_x_poly
# Out:
# array([[1.00000000e+00, 3.20000000e+01, 8.48788200e+01, ...,
#         6.24149290e+02, 3.03643739e+03, 1.47720299e+04],
#        [1.00000000e+00, 1.95000000e+01, 3.06594700e+02, ...,
#         6.24017387e+02, 3.03609828e+03, 1.47718525e+04],
#        [1.00000000e+00, 1.33000000e+01, 5.61984500e+02, ...,
#         6.24373157e+02, 3.03707359e+03, 1.47729221e+04],
#        ...,
#        [1.00000000e+00, 1.88000000e+01, 3.90969600e+02, ...,
#         6.23961931e+02, 3.03597212e+03, 1.47719376e+04],
#        [1.00000000e+00, 8.10000000e+00, 1.04810100e+02, ...,
#         6.23338106e+02, 3.03447431e+03, 1.47721345e+04],
#        [1.00000000e+00, 6.50000000e+00, 9.04560600e+01, ...,
#         6.23717159e+02, 3.03545749e+03, 1.47727252e+04]])

# %%
multi = linear_model.LinearRegression()
lr = multi.fit(train_x, train_y)
print ('Coefficients: ', lr.coef_)
print ('Intercept: ',lr.intercept_)
# Out:
# Coefficients:  [[-2.72497627e-01 -4.34746069e-03  1.32431938e+00  2.20964983e+02
#   -1.26814220e+01]]
# Intercept:  [-3934.22951082]

# %%
from math import sqrt
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

# %%
preds_1 =lr.predict(test_x)

# %%
Results = pd.DataFrame({'Algorithm': [],'MAE': [], 'R^2': [], "MSE":[], "RMSE":[]})

# %%
res = pd.DataFrame({'Algorithm': ['Linear Regression'],'MAE': [mean_absolute_error(test_y, preds_1)], "R^2":[r2_score(test_y, preds_1)], "MSE":[mean_squared_error(test_y, preds_1)],"RMSE":[sqrt(mean_squared_error(test_y, preds_1))]})
 
Results = Results.append(res)

# %%
clf = linear_model.LinearRegression()
train_y_ = clf.fit(train_x_poly, train_y)
# The coefficients
print ('Coefficients: ', clf.coef_)
print ('Intercept: ',clf.intercept_)
# Out:
# Coefficients:  [[ 0.00000000e+00  9.05510939e+02  1.55906183e+01  6.31413780e+03
#    6.24530471e+05  6.23372081e+05  2.05856859e-02 -9.76789971e-06
#    1.70792498e-02 -9.35877626e+00 -5.53712717e+00 -3.09413908e-07
#   -1.41225640e-03 -3.12982742e-01 -6.40112194e-02  1.87993919e-02
#   -1.17848284e+02 -2.77301924e+01  4.17004165e+03 -6.84188034e+03
#   -1.86094749e+03]]
# Intercept:  [-45705172.75723223]

# %%
test_x_poly = poly.fit_transform(test_x)
preds_2 = clf.predict(test_x_poly)

# %%
res = pd.DataFrame({'Algorithm': ['Polynormial Regression'],'MAE': [mean_absolute_error(test_y, preds_2)], "R^2":[r2_score(test_y, preds_2)], "MSE":[mean_squared_error(test_y, preds_2)],"RMSE":[sqrt(mean_squared_error(test_y, preds_2))]})

Results = Results.append(res)

# %%
Results
# Out:
#                 Algorithm       MAE       R^2        MSE      RMSE
# 0       Linear Regression  5.605088  0.630211  50.045667  7.074296
# 0  Polynormial Regression  5.001649  0.714310  38.664074  6.218044
